# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
df['budget'] = df['budget'].fillna(0)
df['gross'] = df['gross'].fillna(0)

# %%
df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 1635    87       6      6  1989       257    6.9     1700.0      2120    3279
# 1600  1424       6      0  1989      2848    5.0      201.0      1936    2110
# 1631  1925       5      4  1989       194    4.5      653.0      1881    3857
# 1629  4582       6      0  1989      3327    4.3     1100.0      2631     144
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
#       star  country     budget       gross  company  runtime
# 5445  2334       55  237000000  2847246203     2253    162.0
# 7445  2241       55  356000000  2797501328     1606    181.0
# 3045  1595       55  200000000  2201647264     2253    194.0
# 6663   524       55  245000000  2069521700     1540    138.0
# 7244  2241       55  321000000  2048359754     1606    149.0
# ...    ...      ...        ...         ...      ...      ...
# 1635  1338       55          0           0      630     95.0
# 1600  2499       55    5000000           0     1637     95.0
# 1631   480       55          0           0      879     92.0
# 1629  1857       55          0           0      470    107.0
# 7667  2463       44          0           0     1787    102.0
#
# [7668 rows x 15 columns]

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country    budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000
# 2              Leigh Brackett       Mark Hamill   United States  18000000
# 3                Jim Abrahams       Robert Hays   United States   3500000
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000
# ...                       ...               ...             ...       ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000
# 7664              Lisa Huston  Michael Saquella   United States         0
# 7665             Lynno Lovert      Onyama Laura   United States     58750
# 7666            James Randall     Christina Roz   United States     15000
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         0
#
#           gross                    company  runtime
# 0      46998772               Warner Bros.    146.0
# 1      58853106          Columbia Pictures    104.0
# 2     538375067                  Lucasfilm    124.0
# 3      83453539         Paramount Pictures     88.0
# 4      39846344             Orion Pictures     98.0
# ...         ...                        ...      ...
# 7663          0                        NaN     90.0
# 7664          0  Cactus Blue Entertainment     90.0
# 7665          0           Embi Productions      NaN
# 7666          0                        NaN    120.0
# 7667          0                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
df
# Out:
#                                             name rating      genre  year  \
# 5445                                      Avatar  PG-13     Action  2009
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 3045                                     Titanic  PG-13      Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# ...                                          ...    ...        ...   ...
# 1216                                     Cyclone      R     Action  1987
# 1209                  No Retreat, No Surrender 2      R  Adventure  1987
# 1201                                      Walker      R  Biography  1987
# 1199                             Walk Like a Man     PG     Comedy  1987
# 7667                                   Tee em el    NaN     Horror  2020
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
# ...                                 ...    ...        ...            ...
# 1216       June 5, 1987 (United States)    4.5      882.0  Fred Olen Ray
# 1209   January 27, 1989 (United States)    5.1     1600.0     Corey Yuen
# 1201   December 4, 1987 (United States)    6.6     3300.0       Alex Cox
# 1199     April 17, 1987 (United States)    4.8     1400.0   Melvin Frank
# 7667    August 19, 2020 (United States)    5.7        7.0   Pereko Mosia
#
#                    writer               star        country     budget  \
# 5445        James Cameron    Sam Worthington  United States  237000000
# 7445   Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045        James Cameron  Leonardo DiCaprio  United States  200000000
# 6663      Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244   Christopher Markus  Robert Downey Jr.  United States  321000000
# ...                   ...                ...            ...        ...
# 1216          Paul Garson     Heather Thomas  United States          0
# 1209  Maria Elena Cellino       Loren Avedon      Hong Kong          0
# 1201       Rudy Wurlitzer          Ed Harris  United States    5800000
# 1199         Robert Klane  Christopher Lloyd  United States          0
# 7667         Pereko Mosia   Siyabonga Mabaso   South Africa          0
#
#            gross                                      company  runtime
# 5445  2847246203                        Twentieth Century Fox    162.0
# 7445  2797501328                               Marvel Studios    181.0
# 3045  2201647264                        Twentieth Century Fox    194.0
# 6663  2069521700                                    Lucasfilm    138.0
# 7244  2048359754                               Marvel Studios    149.0
# ...          ...                                          ...      ...
# 1216           0                                Cinetel Films     89.0
# 1209           0                    Seasonal Film Corporation     92.0
# 1201           0  In-Cine Compañía Industrial Cinematográfica     94.0
# 1199           0                    Metro-Goldwyn-Mayer (MGM)     86.0
# 7667           0                                  PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
# Scatter plot with budget vs gross
plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earings')
plt.xlabel('Gross Earings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime
# 5445  2847246203  Twentieth Century Fox    162.0
# 7445  2797501328         Marvel Studios    181.0
# 3045  2201647264  Twentieth Century Fox    194.0
# 6663  2069521700              Lucasfilm    138.0
# 7244  2048359754         Marvel Studios    149.0

# %%
# plot budget vs gross using seaborn


sns.regplot(x='budget',y='gross',data=df, scatter_kws = {"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True )
plt.title('Correlation matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Looking at companies
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime
# 5445  2847246203  Twentieth Century Fox    162.0
# 7445  2797501328         Marvel Studios    181.0
# 3045  2201647264  Twentieth Century Fox    194.0
# 6663  2069521700              Lucasfilm    138.0
# 7244  2048359754         Marvel Studios    149.0

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
    
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 1216  1405       6      0  1987      1904    4.5      882.0       891    3303
# 1209  3948       6      1  1987      1288    5.1     1600.0       520    2728
# 1201  7211       6      3  1987       845    6.6     3300.0        66    3780
# 1199  7208       4      4  1987        83    4.8     1400.0      1877    3645
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
#       star  country     budget       gross  company  runtime
# 5445  2334       55  237000000  2847246203     2253    162.0
# 7445  2241       55  356000000  2797501328     1606    181.0
# 3045  1595       55  200000000  2201647264     2253    194.0
# 6663   524       55  245000000  2069521700     1540    138.0
# 7244  2241       55  321000000  2048359754     1606    149.0
# ...    ...      ...        ...         ...      ...      ...
# 1216   976       55          0           0      695     89.0
# 1209  1645       17          0           0     2043     92.0
# 1201   701       55    5800000           0     1323     94.0
# 1199   462       55          0           0     1637     86.0
# 7667  2463       44          0           0     1787    102.0
#
# [7668 rows x 15 columns]

# %%
df
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 1635    87       6      6  1989       257    6.9     1700.0      2120    3279
# 1600  1424       6      0  1989      2848    5.0      201.0      1936    2110
# 1631  1925       5      4  1989       194    4.5      653.0      1881    3857
# 1629  4582       6      0  1989      3327    4.3     1100.0      2631     144
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
#       star  country     budget       gross  company  runtime
# 5445  2334       55  237000000  2847246203     2253    162.0
# 7445  2241       55  356000000  2797501328     1606    181.0
# 3045  1595       55  200000000  2201647264     2253    194.0
# 6663   524       55  245000000  2069521700     1540    138.0
# 7244  2241       55  321000000  2048359754     1606    149.0
# ...    ...      ...        ...         ...      ...      ...
# 1635  1338       55          0           0      630     95.0
# 1600  2499       55    5000000           0     1637     95.0
# 1631   480       55          0           0      879     92.0
# 1629  1857       55          0           0      470    107.0
# 7667  2463       44          0           0     1787    102.0
#
# [7668 rows x 15 columns]

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True )
plt.title('Correlation matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
pd.set_option('display.max_rows', None)

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name      name        1.000000
#           rating      0.344557
#           genre       0.138371
#           year        0.253897
#           released    0.656279
#           score       0.107024
#           votes       0.595745
#           director    0.720111
#           writer      0.782939
#           star        0.653290
#           country     0.193872
#           budget      0.111235
#           gross       0.978147
#           company     0.686237
#           runtime     0.071777
# rating    name        0.344557
#           rating      1.000000
#           genre      -0.014784
#           year        0.036004
#           released    0.263764
#           score      -0.069097
#           votes       0.154176
#           director    0.284006
#           writer      0.303190
#           star        0.303967
#           country     0.199683
#           budget      0.083560
#           gross       0.351587
#           company     0.334675
#           runtime     0.033730
# genre     name        0.138371
#           rating     -0.014784
#           genre       1.000000
#           year        0.087977
#           released    0.090981
#           score       0.063222
#           votes       0.148527
#           director    0.093449
#           writer      0.088198
#           star        0.099732
#           country    -0.072434
#           budget      0.101276
#           gross       0.134001
#           company     0.057767
#           runtime     0.005585
# year      name        0.253897
#           rating      0.036004
#           genre       0.087977
#           year        1.000000
#           released    0.315356
#           score       0.076737
#           votes       0.326459
#           director    0.173224
#           writer      0.212387
#           star        0.228029
#           country    -0.055861
#           budget      0.060244
#           gross       0.266957
#           company     0.123360
#           runtime     0.032916
# released  name        0.656279
#           rating      0.263764
#           genre       0.090981
#           year        0.315356
#           released    1.000000
#           score       0.069410
#           votes       0.449835
#           director    0.502072
#           writer      0.546852
#           star        0.476492
#           country     0.163532
#           budget      0.080345
#           gross       0.669825
#           company     0.467316
#           runtime     0.046192
# score     name        0.107024
#           rating     -0.069097
#           genre       0.063222
#           year        0.076737
#           released    0.069410
#           score       1.000000
#           votes       0.233445
#           director    0.149659
#           writer      0.103779
#           star        0.106931
#           country    -0.095521
#           budget      0.001145
#           gross       0.113338
#           company     0.037341
#           runtime     0.035609
# votes     name        0.595745
#           rating      0.154176
#           genre       0.148527
#           year        0.326459
#           released    0.449835
#           score       0.233445
#           votes       1.000000
#           director    0.495019
#           writer      0.521325
#           star        0.452171
#           country     0.051182
#           budget      0.038545
#           gross       0.611780
#           company     0.392608
#           runtime     0.067696
# director  name        0.720111
#           rating      0.284006
#           genre       0.093449
#           year        0.173224
#           released    0.502072
#           score       0.149659
#           votes       0.495019
#           director    1.000000
#           writer      0.696216
#           star        0.581025
#           country     0.195402
#           budget      0.043342
#           gross       0.737284
#           company     0.616872
#           runtime     0.080156
# writer    name        0.782939
#           rating      0.303190
#           genre       0.088198
#           year        0.212387
#           released    0.546852
#           score       0.103779
#           votes       0.521325
#           director    0.696216
#           writer      1.000000
#           star        0.590599
#           country     0.198926
#           budget      0.064082
#           gross       0.797866
#           company     0.618771
#           runtime     0.057827
# star      name        0.653290
#           rating      0.303967
#           genre       0.099732
#           year        0.228029
#           released    0.476492
#           score       0.106931
#           votes       0.452171
#           director    0.581025
#           writer      0.590599
#           star        1.000000
#           country     0.219986
#           budget      0.066926
#           gross       0.669962
#           company     0.573684
#           runtime     0.074104
# country   name        0.193872
#           rating      0.199683
#           genre      -0.072434
#           year       -0.055861
#           released    0.163532
#           score      -0.095521
#           votes       0.051182
#           director    0.195402
#           writer      0.198926
#           star        0.219986
#           country     1.000000
#           budget     -0.060810
#           gross       0.194529
#           company     0.257649
#           runtime     0.014856
# budget    name        0.111235
#           rating      0.083560
#           genre       0.101276
#           year        0.060244
#           released    0.080345
#           score       0.001145
#           votes       0.038545
#           director    0.043342
#           writer      0.064082
#           star        0.066926
#           country    -0.060810
#           budget      1.000000
#           gross       0.107239
#           company     0.065132
#           runtime     0.063789
# gross     name        0.978147
#           rating      0.351587
#           genre       0.134001
#           year        0.266957
#           released    0.669825
#           score       0.113338
#           votes       0.611780
#           director    0.737284
#           writer      0.797866
#           star        0.669962
#           country     0.194529
#           budget      0.107239
#           gross       1.000000
#           company     0.698374
#           runtime     0.072440
# company   name        0.686237
#           rating      0.334675
#           genre       0.057767
#           year        0.123360
#           released    0.467316
#           score       0.037341
#           votes       0.392608
#           director    0.616872
#           writer      0.618771
#           star        0.573684
#           country     0.257649
#           budget      0.065132
#           gross       0.698374
#           company     1.000000
#           runtime     0.058009
# runtime   name        0.071777
#           rating      0.033730
#           genre       0.005585
#           year        0.032916
#           released    0.046192
#           score       0.035609
#           votes       0.067696
#           director    0.080156
#           writer      0.057827
#           star        0.074104
#           country     0.014856
#           budget      0.063789
#           gross       0.072440
#           company     0.058009
#           runtime     1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# country   score      -0.095521
# score     country    -0.095521
# country   genre      -0.072434
# genre     country    -0.072434
# rating    score      -0.069097
# score     rating     -0.069097
# budget    country    -0.060810
# country   budget     -0.060810
#           year       -0.055861
# year      country    -0.055861
# genre     rating     -0.014784
# rating    genre      -0.014784
# budget    score       0.001145
# score     budget      0.001145
# runtime   genre       0.005585
# genre     runtime     0.005585
# country   runtime     0.014856
# runtime   country     0.014856
# year      runtime     0.032916
# runtime   year        0.032916
#           rating      0.033730
# rating    runtime     0.033730
# score     runtime     0.035609
# runtime   score       0.035609
# rating    year        0.036004
# year      rating      0.036004
# company   score       0.037341
# score     company     0.037341
# votes     budget      0.038545
# budget    votes       0.038545
#           director    0.043342
# director  budget      0.043342
# runtime   released    0.046192
# released  runtime     0.046192
# votes     country     0.051182
# country   votes       0.051182
# genre     company     0.057767
# company   genre       0.057767
# writer    runtime     0.057827
# runtime   writer      0.057827
# company   runtime     0.058009
# runtime   company     0.058009
# year      budget      0.060244
# budget    year        0.060244
# score     genre       0.063222
# genre     score       0.063222
# budget    runtime     0.063789
# runtime   budget      0.063789
# writer    budget      0.064082
# budget    writer      0.064082
# company   budget      0.065132
# budget    company     0.065132
#           star        0.066926
# star      budget      0.066926
# votes     runtime     0.067696
# runtime   votes       0.067696
# released  score       0.069410
# score     released    0.069410
# runtime   name        0.071777
# name      runtime     0.071777
# gross     runtime     0.072440
# runtime   gross       0.072440
# star      runtime     0.074104
# runtime   star        0.074104
# score     year        0.076737
# year      score       0.076737
# director  runtime     0.080156
# runtime   director    0.080156
# budget    released    0.080345
# released  budget      0.080345
# budget    rating      0.083560
# rating    budget      0.083560
# genre     year        0.087977
# year      genre       0.087977
# writer    genre       0.088198
# genre     writer      0.088198
# released  genre       0.090981
# genre     released    0.090981
# director  genre       0.093449
# genre     director    0.093449
# star      genre       0.099732
# genre     star        0.099732
# budget    genre       0.101276
# genre     budget      0.101276
# score     writer      0.103779
# writer    score       0.103779
# star      score       0.106931
# score     star        0.106931
#           name        0.107024
# name      score       0.107024
# gross     budget      0.107239
# budget    gross       0.107239
#           name        0.111235
# name      budget      0.111235
# gross     score       0.113338
# score     gross       0.113338
# company   year        0.123360
# year      company     0.123360
# genre     gross       0.134001
# gross     genre       0.134001
# genre     name        0.138371
# name      genre       0.138371
# votes     genre       0.148527
# genre     votes       0.148527
# score     director    0.149659
# director  score       0.149659
# rating    votes       0.154176
# votes     rating      0.154176
# country   released    0.163532
# released  country     0.163532
# director  year        0.173224
# year      director    0.173224
# country   name        0.193872
# name      country     0.193872
# gross     country     0.194529
# country   gross       0.194529
# director  country     0.195402
# country   director    0.195402
#           writer      0.198926
# writer    country     0.198926
# rating    country     0.199683
# country   rating      0.199683
# writer    year        0.212387
# year      writer      0.212387
# country   star        0.219986
# star      country     0.219986
#           year        0.228029
# year      star        0.228029
# score     votes       0.233445
# votes     score       0.233445
# name      year        0.253897
# year      name        0.253897
# company   country     0.257649
# country   company     0.257649
# released  rating      0.263764
# rating    released    0.263764
# gross     year        0.266957
# year      gross       0.266957
# director  rating      0.284006
# rating    director    0.284006
#           writer      0.303190
# writer    rating      0.303190
# star      rating      0.303967
# rating    star        0.303967
# released  year        0.315356
# year      released    0.315356
#           votes       0.326459
# votes     year        0.326459
# rating    company     0.334675
# company   rating      0.334675
# rating    name        0.344557
# name      rating      0.344557
# gross     rating      0.351587
# rating    gross       0.351587
# company   votes       0.392608
# votes     company     0.392608
# released  votes       0.449835
# votes     released    0.449835
#           star        0.452171
# star      votes       0.452171
# company   released    0.467316
# released  company     0.467316
#           star        0.476492
# star      released    0.476492
# director  votes       0.495019
# votes     director    0.495019
# released  director    0.502072
# director  released    0.502072
# votes     writer      0.521325
# writer    votes       0.521325
#           released    0.546852
# released  writer      0.546852
# star      company     0.573684
# company   star        0.573684
# star      director    0.581025
# director  star        0.581025
# writer    star        0.590599
# star      writer      0.590599
# name      votes       0.595745
# votes     name        0.595745
#           gross       0.611780
# gross     votes       0.611780
# director  company     0.616872
# company   director    0.616872
#           writer      0.618771
# writer    company     0.618771
# star      name        0.653290
# name      star        0.653290
# released  name        0.656279
# name      released    0.656279
# released  gross       0.669825
# gross     released    0.669825
#           star        0.669962
# star      gross       0.669962
# name      company     0.686237
# company   name        0.686237
# director  writer      0.696216
# writer    director    0.696216
# gross     company     0.698374
# company   gross       0.698374
# director  name        0.720111
# name      director    0.720111
# gross     director    0.737284
# director  gross       0.737284
# writer    name        0.782939
# name      writer      0.782939
# writer    gross       0.797866
# gross     writer      0.797866
#           name        0.978147
# name      gross       0.978147
#           name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
